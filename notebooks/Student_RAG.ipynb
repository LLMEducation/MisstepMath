# %%
# Install necessary libraries
# !pip install openai
# !pip install openai pandas faiss-cpu sentence-transformers

# Import required libraries
import openai
import pandas as pd
import faiss
import numpy as np
import json
import time
import os
from openai import OpenAI
from sentence_transformers import SentenceTransformer

# Set OpenAI API credentials
secret_key = ''
organization_id = ''
openai.organization = organization_id
openai.api_key = secret_key
os.environ["OPENAI_API_KEY"] = secret_key
client = OpenAI(organization=organization_id)

# Load Sentence Transformer model for embedding retrieval
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# Define file paths
train_dataset_path = "data/train_dataset.json"
selected_combinations_path = "data/selected_50_unique_rows_teacher_model.csv"
output_csv_path = "data/student_rag_results.csv"
output_copy_csv_path = "data/student_rag_results_copy.csv"

# Load the train dataset (RAG database)
train_data={}
with open(train_dataset_path, "r", encoding="utf-8") as file:
    train_data = json.load(file)
rag_df = pd.DataFrame(train_data)
selected_combinations = pd.read_csv(selected_combinations_path)

# Create a FAISS index for fast retrieval
embeddings = embedding_model.encode(rag_df["Student's mistake prompt"].tolist(), convert_to_numpy=True)
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

# Function to retrieve relevant context from RAG database
def retrieve_context(query, top_k=3):
    query_embedding = embedding_model.encode([query], convert_to_numpy=True)
    distances, indices = index.search(query_embedding, top_k)
    retrieved = rag_df.iloc[indices[0]][["Challenge Type", "Problem", "Student's mistake prompt"]].to_dict(orient='records')
    return retrieved

# Function to generate student mistakes with RAG

def generate_student_mistake_rag(grade, topic, sub_topic):
    query = f"Common mistakes in {sub_topic} within {topic} for grade {grade} students."
    retrieved_contexts = retrieve_context(query)
    context_str = "\n".join([json.dumps(ctx) for ctx in retrieved_contexts])

    prompt = (
        f"Given the following examples of student mistakes: {context_str}\n"
        f"Generate a divervent diverse stduent mistake for a grade:{grade} student with topic:{topic} in sub-topic:{sub_topic}."
        f"Output only JSON format (valid): {{\"challenge_type\":\"<type>\", \"question\":\"<math problem>\", \"mistake\":\"<student's mistake>\"}}"
    )

    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",  # Use GPT-4 or another model
            messages=[{"role": "user", "content": prompt}],
            max_tokens=500
        )
        output = response.choices[0].message.content.strip()
        if "```json" in output:
          o = output.split("```json")[1].split("```")[0]
        else:
          o = output
        return json.loads(o)
    except Exception as e:
        print(f"Error: {e}")
        return None

# Generate dataset using RAG-enhanced model
math_data = []
num_samples = 100

for _, row in selected_combinations.iterrows():
    grade, topic, sub_topic = row["Grade"], row["Topic"], row["Sub Topic"]

    for _ in range(num_samples):
        print(f"📝 Generating sample for: {grade}, {topic}, {sub_topic}")
        response = generate_student_mistake_rag(grade, topic, sub_topic)

        if response:
            print(response)
            challenge_type, question, mistake = response["challenge_type"], response["question"], response["mistake"]
            math_data.append([grade, topic, sub_topic, challenge_type, question, mistake])


            extracted_data = pd.DataFrame([{"Grade":grade, "Topic":topic, "Sub Topic":sub_topic, "Challenge Type":challenge_type, "Problem":question, "Student Mistake Prompt":mistake}])

            if not os.path.exists(output_csv_path):
                extracted_data.to_csv(output_csv_path, index=False)
            else:
                extracted_data.to_csv(output_csv_path, mode='a', header=False, index=False)

        time.sleep(1)  # Avoid rate limits

# Convert to DataFrame
math_df = pd.DataFrame(math_data, columns=["Grade", "Topic", "Sub Topic", "Challenge Type", "Problem", "Student Mistake Prompt"])

# Save dataset to Google Drive
math_df.to_csv(output_copy_csv_path, index=False)
print(f"Dataset generation complete. Saved at: {output_copy_csv_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student holds the ruler upside down and measures in centimeters instead of inches.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the length of the ruler itself instead of the toy car.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Use a ruler to measure the length of a crayon.', 'mistake': 'Student measures the length and width of the crayon instead of just the length.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Conceptual Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student measures the length of the eraser instead of the pencil.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student measures the pencil but starts from the wrong end of the ruler, resulting in an incorrect reading.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student measures the length of the ruler instead of the pencil.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student only measures half of the crayon and does not account for the other half.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student only measures the length of the wheels, ignoring the full length of the car.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student only measures the height of the car instead of its length.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure how long your pencil is in inches.', 'mistake': 'Student measures the length of the pencil but forgets to include the eraser.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the length of the ruler instead of the length of the toy car.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of your pencil using a ruler.', 'mistake': 'Student holds the ruler upside down and measures from the wrong end.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student measures the length of the eraser instead of the pencil.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a string using a ruler.', 'mistake': 'Student only measures a portion of the string, not the entire length.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a shoelace in inches.', 'mistake': 'Student measures the length but does not include the ends of the shoelace, missing an inch.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car that is 3.75 inches long.', 'mistake': 'Student places the ruler only at one end of the car and measures 3 inches, missing the .75 inches.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student holds the ruler upside down, causing them to read the measurement incorrectly.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the height of a toy block using a ruler.', 'mistake': 'Student only measures the height of the block but forgets to start from the base, measuring from mid-air instead.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Use a ruler to measure the length of your pencil in inches.', 'mistake': 'Student measures the length of the eraser instead of the pencil.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student measures the length of the wrapper instead of the crayon itself.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student focuses only on the visible part of the car and measures without considering the entire length, missing the back part.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student focuses on the number of inches and accidentally overlooks the fractional part, reporting only 3 inches instead of 3.25 inches.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Compare the lengths of a pencil and a crayon using a ruler.', 'mistake': 'Student only compares the pencil to the ruler and ignores the crayon.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student holds the ruler upside down and measures from the wrong side.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student places the ruler parallel to the pencil and does not see where the pencil ends, measuring only the visible part.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': "Student measures the length of the car's wheels instead of the entire car."}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student measures the crayon but holds the ruler upside down, reading the wrong side.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student only measures the length of the crayon tip and ignores the entire crayon length.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student measures the pencil but starts from the wrong end of the ruler.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student focuses only on measuring the height of the car, ignoring its length.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the overall height of the car instead of its length.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Use a ruler to measure the length of a pencil.', 'mistake': 'Student places the pencil at an angle and measures the diagonal length instead of the straight length.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a branch that is 3.75 inches long.', 'mistake': 'Student measures the length but only counts the whole inches and ignores the .75.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the length from the back to the front of the car but forgets to include the front bumper.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon in inches.', 'mistake': 'Student measures the length of the crayon with a ruler but starts from the middle instead of the end.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Use a ruler to measure the length of a pencil in inches.', 'mistake': 'Student fails to start measuring from the zero mark on the ruler and measures from the 1-inch mark instead.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car in inches.', 'mistake': 'Student measures the length but forgets to include the front bumper.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student holds the ruler upside down and measures from the wrong starting point.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon in inches.', 'mistake': 'Student measures the length but forgets to include the part of the crayon that is broken.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student measures the length of the crayon but forgets to start at the 0 mark on the ruler, measuring from the 1-inch mark instead.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Use a ruler to measure the length of a toy car.', 'mistake': 'Student measures the length of the car but forgets to align the ruler to the start of the car, measuring to the end of the ruler instead.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student measures the length of the crayon but does not account for the part that is sharpened, reporting it as shorter than it really is.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the length of the ruler instead of the toy car.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of your pencil using a ruler.', 'mistake': 'Student measures the length of the ruler itself instead of the pencil.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a spoon using a ruler.', 'mistake': 'Student measures the length of the spoon but forgets to start from the very end, missing part of the measurement.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the length of the ruler instead of the toy car.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student measures from the middle of the crayon instead of one end to the other.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of your pencil using a ruler.', 'mistake': 'Student holds the ruler upside down and measures from the wrong side, giving an incorrect length.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Use a ruler to measure the length of a pencil in inches.', 'mistake': 'Student measures the length of the pencil but forgets to start from the zero mark on the ruler, resulting in an inaccurate measurement.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon that is 3 and 3/4 inches long.', 'mistake': 'Student measures only up to 3 inches, ignoring the 3/4 inch.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of your pencil using a ruler.', 'mistake': 'Student measures the length of the pencil but holds the ruler upside down, reading the measurement incorrectly.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the length of the ruler instead of the toy car.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student measures the pencil but only counts whole inches and ignores the extra fraction at the end.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Using a ruler, measure the length of a pencil that is 5 and 3/4 inches long.', 'mistake': 'Student only measures up to 5 inches and ignores the additional 3/4 inch.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a piece of yarn using a ruler.', 'mistake': 'Student measures the yarn without starting at the zero mark on the ruler, leading to an incorrect measurement.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of the string shown to you.', 'mistake': 'Student measures the string but does not include the extra 1/4 inch that extends past the ruler.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student measures the length of the crayon but forgets to start at the zero mark on the ruler.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the length of the ruler instead of the toy car.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': "Student only measures the length of the crayon without starting from the '0' mark on the ruler."}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a string that is 4.3 inches long.', 'mistake': 'Student measures the length but only counts 4 inches without considering the .3 inches.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of your pencil using a ruler.', 'mistake': 'Student starts measuring from the middle of the pencil instead of the end.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon in inches.', 'mistake': 'Student measures the length of the crayon but does not include the tip, resulting in a shorter measurement.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the length of the car but forgets to include the part that sticks out, like the wheels.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the length of the ruler itself instead of the toy car.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student measures the pencil but does not start from the zero mark on the ruler.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the length of the ruler itself instead of the toy car.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student only measures the length of the pencil without considering the small eraser at the end.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a piece of yarn that is 3.5 inches long.', 'mistake': 'Student measures the yarn but does not include the extra half inch, reporting it as 3 inches.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student measures the length of the crayon but starts from the wrong end of the ruler, resulting in an incorrect measurement.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a string using a ruler.', 'mistake': 'Student measures the string but forgets to start at the zero mark, resulting in an incorrect reading.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student starts measuring from the wrong end of the crayon, not aligning the ruler properly.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': "Student measures the length but doesn't account for the wheels, only measuring the body."}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the length of the car but forgets to start from the zero mark on the ruler, leading to an inaccurate measurement.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car in inches.', 'mistake': 'Student measures the length of the car but forgets to include the length of the wheels.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a piece of string using a ruler.', 'mistake': 'Student measures the length of the string using the wrong side of the ruler, resulting in an inaccurate reading.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a block using a ruler.', 'mistake': 'Student places the ruler but only looks at the number on the end of the block, ignoring the start of the ruler.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student measures the length of the pencil but does not start from the zero mark on the ruler.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student measures from the eraser to the tip instead of the body of the pencil.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Use a ruler to measure the length of a crayon.', 'mistake': 'Student measures the length of the crayon by only looking at the inch numbers and ignores the smaller markings for fractions.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student reads the measurement at the wrong side of the ruler, measuring 4 inches instead of 5 inches.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student measures the length of the pencil but does not measure from the end to the tip, starting instead from the middle.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the car but does not start at the zero mark on the ruler, leading to an inaccurate measurement.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student only measures the width of the car instead of the length.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil.', 'mistake': 'Student only measures the eraser part of the pencil, ignoring the shaft.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student measures the height of the pencil instead of its length.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Use a ruler to measure the length of a crayon that is 4 inches long.', 'mistake': 'Student only measures the crayon without including the crayon wrapper and reports it as 3 inches.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a string that is 3.75 inches long.', 'mistake': 'Student measures only 3 inches and ignores the .75.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student measures the length of the pencil but forgets to start at the zero mark on the ruler.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': "Student measures the crayon's length but does not start from the zero mark on the ruler."}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student measures the crayon but forgets to start from the zero mark on the ruler.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a piece of string using a ruler.', 'mistake': 'Student measures the string only up to the nearest whole inch, ignoring any fractional parts.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': 'Student only measures the length of the pencil but does not include the eraser at the end.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of your desk using a piece of string.', 'mistake': 'Student measures the string itself instead of the desk.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the length of the ruler instead of the toy car.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of your pencil using a ruler.', 'mistake': 'Student measures from the eraser end instead of the sharpened end.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a toy car using a ruler.', 'mistake': 'Student measures the length of the car from the back to the front but forgets to include the length of the wheels.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': "Student holds the ruler vertically and measures the crayon's height instead of its length."}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a pencil using a ruler.', 'mistake': "Student measures the pencil's length but only counts whole inches, ignoring the smaller fractions."}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student measures the length of the ruler instead of the crayon.'}
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# {'challenge_type': 'Attention Error', 'question': 'Measure the length of a crayon using a ruler.', 'mistake': 'Student places the ruler next to the crayon but does not start measuring from the zero mark.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student adds the lengths of the two legs instead of squaring them and applying the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Calculate the length of the hypotenuse for a right triangle with legs of 5 cm and 12 cm.', 'mistake': 'Student uses the formula for the area of a triangle instead of applying the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Find the length of the hypotenuse of a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student attempts to add the lengths of the legs instead of using the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse of a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student incorrectly believes the hypotenuse is the sum of the legs instead of using the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student tries to add the lengths of the legs instead of applying the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse of a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student mistakenly adds the lengths of the legs instead of applying the Pythagorean Theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse of a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student incorrectly adds the lengths of the legs instead of using the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine if a triangle with sides of lengths 5 cm, 12 cm, and 13 cm is a right triangle using the Pythagorean Theorem.', 'mistake': 'Student incorrectly assumes that all triangles with these side lengths are right triangles without applying the theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse of a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student believes the hypotenuse is the sum of the two legs rather than using the Pythagorean Theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'A ladder leans against a wall, forming a right triangle with the ground. If the base of the ladder is 6 feet from the wall and the ladder is 10 feet long, how high up the wall does the ladder reach?', 'mistake': 'Student tries to calculate the height by adding the lengths of the ladder and the base instead of using the Pythagorean Theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student thinks the hypotenuse can be found by simply adding the lengths of the legs instead of using the Pythagorean Theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'A ladder is leaning against a wall, forming a right triangle. If the ladder is 10 feet long and the base of the ladder is 6 feet from the wall, find the height where the ladder touches the wall using the Pythagorean theorem.', 'mistake': "Student believes the ladder's height is simply half the length of the ladder, incorrectly assuming a 45-degree angle."}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine if the triangle with sides 5 cm, 12 cm, and 13 cm is a right triangle by applying the Pythagorean theorem.', 'mistake': "Student mistakenly assumes it's necessary to check the ratios of sides instead of using the Pythagorean theorem."}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Calculate the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student adds the lengths of the legs instead of applying the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle where the other two sides are 5 cm and 12 cm.', 'mistake': 'Student adds the lengths of the two sides instead of using the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student adds the lengths of the legs instead of using the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle where the legs are 5 cm and 12 cm.', 'mistake': 'Attempts to add the two legs instead of applying the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine if the triangle with sides measuring 5 cm, 12 cm, and 13 cm is a right triangle.', 'mistake': 'Student incorrectly states that the triangle is not a right triangle, despite it satisfying the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse of a right triangle where the legs are 5 cm and 12 cm.', 'mistake': 'Student tries to add the lengths of the legs instead of squaring them and applying the Pythagorean Theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student uses addition of the lengths of the legs instead of applying the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs of length 5 cm and 12 cm.', 'mistake': 'Student calculates the perimeter of the triangle instead of the hypotenuse.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine if a given triangle with sides 5 cm, 12 cm, and 13 cm is a right triangle using the Pythagorean Theorem.', 'mistake': 'Student incorrectly identifies the triangle as right because they only check two sides instead of all three.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student incorrectly states that the hypotenuse is found by adding the lengths of the legs instead of using the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student incorrectly assumes that the hypotenuse is simply the sum of the two legs.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student adds the lengths of the legs instead of applying the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student applies the Pythagorean theorem but confuses the legs and the hypotenuse, using the wrong values.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse of a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student adds the lengths of the legs instead of using the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Procedural Error', 'question': 'Determine the length of the hypotenuse in a right triangle where one leg is 5 cm and the other leg is 12 cm.', 'mistake': 'Student incorrectly adds the lengths of the legs instead of applying the Pythagorean Theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student adds the lengths of the two legs instead of using the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse of a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student attempts to add the lengths of the two legs instead of using the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student attempts to find the hypotenuse by adding the lengths of the legs instead of using the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right-angled triangle where the other two sides are 5 cm and 12 cm.', 'mistake': 'Student attempts to add the lengths of the two sides instead of using the Pythagorean Theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student calculates the length of one of the legs instead of applying the Pythagorean Theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Find the length of the hypotenuse of a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student incorrectly assumes that the hypotenuse is the sum of the lengths of the legs.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine if the triangle with sides 5 cm, 12 cm, and 13 cm is a right triangle using the Pythagorean Theorem.', 'mistake': 'Student incorrectly assumes that all triangles with integer sides are right triangles without applying the theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine whether the triangle with sides 5 cm, 12 cm, and 15 cm is a right triangle using the Pythagorean Theorem.', 'mistake': 'Student incorrectly concludes it is a right triangle by adding the sides instead of applying the theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Calculates the perimeter of the triangle instead of finding the hypotenuse.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine if a triangle with sides 5 cm, 12 cm, and 13 cm is a right triangle using the Pythagorean theorem.', 'mistake': 'Student states the triangle is not a right triangle and does not apply the theorem correctly.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the distance between two points (3, 4) and (7, 1) using the Pythagorean Theorem.', 'mistake': 'Student attempts to calculate the slope instead of the distance using the correct theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine if the triangle with sides 5 cm, 12 cm, and 13 cm is a right triangle using the Pythagorean theorem.', 'mistake': 'Student mistakenly assumes a triangle with these side lengths cannot be a right triangle and tries to calculate the area instead.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student calculates the perimeter of the triangle instead of using the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine if a triangle with sides 5 cm, 12 cm, and 13 cm is a right triangle using the Pythagorean Theorem.', 'mistake': 'Student incorrectly identifies the triangle as a right triangle by adding the sides instead of applying the Pythagorean Theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student incorrectly uses addition of the two legs instead of applying the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse of a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student confuses the lengths of the legs with the length of the hypotenuse and uses them as the sides in the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine if a triangle with sides 5 cm, 12 cm, and 13 cm is a right triangle using the Pythagorean Theorem.', 'mistake': 'Student incorrectly adds the lengths of the sides instead of applying the theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student calculates the perimeter instead of the hypotenuse.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Calculate the length of the hypotenuse in a right triangle where the legs measure 5 cm and 12 cm.', 'mistake': 'Student subtracts the lengths of the legs instead of using the Pythagorean Theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse of a triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student adds the lengths of the legs instead of using the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine if the triangle with sides 5 cm, 12 cm, and 13 cm is a right triangle using the Pythagorean Theorem.', 'mistake': 'Student incorrectly assumes that the triangle does not need to be a right triangle to apply the Pythagorean Theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student thinks the hypotenuse is the sum of the two legs instead of using the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Use the Pythagorean Theorem to find the length of the missing side in a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student incorrectly adds the lengths of the legs instead of applying the Pythagorean theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# {'challenge_type': 'Conceptual Error', 'question': 'Determine the length of the hypotenuse of a right triangle with legs measuring 5 cm and 12 cm.', 'mistake': 'Student thinks the hypotenuse is the sum of the legs instead of using the Pythagorean Theorem.'}
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ...
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count and write the number of stars in a group of 1,243 stars.', 'mistake': 'Student counts incorrectly because they were distracted by noises in the classroom.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count and write the number of stars on a page with large numbers of stars.', 'mistake': 'Student loses track of counting and writes down random numbers.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'What is 3,245 + 1,758?', 'mistake': 'Student misreads one of the numbers and writes down the wrong addition.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Place Value Error', 'question': 'What is the value of the digit 3 in the number 3,452,178?', 'mistake': 'Confuses place value and states that the value of 3 is 3 instead of 3,000,000.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the total number of apples if there are 1,234 apples in one basket and 2,345 apples in another basket.', 'mistake': 'Gets distracted by noise in the classroom and miscounts, resulting in an incorrect total.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Counting Error', 'question': 'Count the number of stars in a large cluster of stars up to 1 million.', 'mistake': 'Student loses track of counting after reaching a large number, resulting in an incorrect total.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Conceptual Error', 'question': 'What is 1,000,000 plus 500,000?', 'mistake': 'Student misinterprets the zeros, incorrectly adding the numbers as if they were smaller values.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of apples in a basket that has 1,234 apples.', 'mistake': 'Student loses track while counting and skips some numbers.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of apples in a basket with 1,250 apples.', 'mistake': 'Student counts some apples multiple times due to distractions in the classroom.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Counting Error', 'question': 'Count how many apples are in a basket containing 1,235 apples.', 'mistake': 'Student miscounts the apples due to losing track after several large numbers.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of dots in a large grid up to one million.', 'mistake': 'Student miscounts because they lose track after counting many dots and forgets to double-check.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Write the number that comes after 1,000,000.', 'mistake': 'Student mistakenly writes 1,000 instead of 1,000,001 due to distraction.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'What is the total when you add 1,234,567 and 890,123?', 'mistake': 'Student misreads the numbers and writes down 1,234,678 instead.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Number Recognition Error', 'question': 'What is 5,432 + 6,789?', 'mistake': 'Student misreads the numbers due to their length, leading to incorrect addition.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Identify the number that comes before 1,000,000.', 'mistake': 'Student misreads the number due to focus on surrounding noises, responding with an incorrect answer.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Write the number that comes after 1,245,679.', 'mistake': 'Student writes 1,245,689 due to not paying attention to the digits.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of apples in a group of 1,234 apples.', 'mistake': 'Student miscounts the apples due to being distracted by a noise in the classroom.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Identify the number that comes after 1,234,567.', 'mistake': 'Student writes down the wrong number because they are distracted by a noise in the classroom.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'What is 3,245 + 2,678?', 'mistake': 'Student misreads a number due to distractions in the classroom.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'What is 2,345 + 1,234?', 'mistake': 'Student incorrectly writes the sum as 3,456 because they were distracted by a classmate.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Circle the numbers that are greater than 500,000 in the list: 400,000; 600,000; 800,000; 200,000.', 'mistake': 'Student circles incorrect numbers due to distractions in the classroom.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of blocks in a set of 1,000 blocks.', 'mistake': 'Student miscounts the blocks due to losing focus and skipping some.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Counting Error', 'question': 'Count and write the number of apples in a group containing 1,234 apples.', 'mistake': 'Student miscounts and writes down a much smaller number due to losing track while counting.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of apples in a basket containing 1,234 apples.', 'mistake': 'Student loses track of the count due to distractions in the classroom.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of stars in a large field and write the number down.', 'mistake': 'Student counts correctly but misplaces the decimal point due to getting distracted by a moving object.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of apples in a basket containing up to 1,000 apples.', 'mistake': 'Student miscounts the apples due to distractions in the classroom.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the total number of apples in a basket with 1 million apples, if you remove 5 apples.', 'mistake': 'Student loses track while counting and miscounts the total due to distraction.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count and write the number of stars in a group of 1,234 stars.', 'mistake': 'Student miscounts and writes down an incorrect number due to losing focus.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Write the number that comes after 1,000,000', 'mistake': "Student writes '1,000,100' because they got distracted by a noise."}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Conceptual Error', 'question': 'What is 2,345 + 1,567?', 'mistake': 'Student misreads the numbers due to their length, leading to incorrect addition.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of stars in a large group, estimated to be in the millions.', 'mistake': 'Student miscounts due to distraction and loses track of the total.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Understanding Place Value Error', 'question': 'What is the value of the digit 7 in the number 7,432,891?', 'mistake': 'Confuses place value and states the value as 7 instead of 700,000.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of apples in a picture of 1,234 apples.', 'mistake': 'Student miscounts the apples while distracted by other objects in the picture.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Counting Error', 'question': 'Count the number of apples if there are 1,203 apples in a basket.', 'mistake': 'Student counts incorrectly because they lose track after several hundred.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Whole Number Understanding Error', 'question': 'What is 2,345,678 + 1,234,432?', 'mistake': 'Student confuses the place values, adding them incorrectly due to misunderstanding large numbers.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'What is 2,345 + 3,678?', 'mistake': 'Student misreads the numbers due to being distracted by noise in the classroom.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Number Recognition Error', 'question': 'Count how many marbles are in a jar containing 1,234 marbles and write the number down.', 'mistake': 'Student miscounts and writes down a similar but incorrect number like 1,243 due to confusion with place value.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of jellybeans in a jar and write the total.', 'mistake': 'Student counts incorrectly because they get distracted by the colors of the jellybeans.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of stars in the following group: ★★★★★★★★', 'mistake': 'Student counts incorrectly because they lose track after a few stars.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Number Recognition Error', 'question': 'Count the number of apples in a basket that has 1,000 apples.', 'mistake': 'Student counts incorrectly by skipping some apples while counting.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Identify the number of apples if there are 2,345 apples in the basket.', 'mistake': 'Student counts incorrectly because they become distracted by noise in the classroom.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of stars in a large star chart and write the total number down.', 'mistake': 'Student loses focus and miscounts the stars, writing down an incorrect total.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Place Value Error', 'question': 'Write the number that is one million less than 2,345,678.', 'mistake': 'Student confuses place value and writes 1,345,678 instead.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count and write the number of apples in a basket containing 1,234 apples.', 'mistake': 'Student loses focus and writes down an incorrect number like 1,243 instead of 1,234.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of apples in a basket containing 1,234 apples.', 'mistake': 'Student miscounts the apples because they are distracted by a conversation happening nearby.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Countability Error', 'question': 'Write the number that comes after 999,999.', 'mistake': 'Student writes 1,000 instead of 1,000,000 because they miscount the place value.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Conceptual', 'question': 'How many hundreds are there in the number 5,432,100?', 'mistake': 'Student counts incorrectly due to confusion about large numbers and place value.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the total number of stars displayed on a page (48,762 stars).', 'mistake': 'Student miscounts the stars due to getting distracted by other objects on the page.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'What is 2,345 + 1,678?', 'mistake': 'Student misreads the numbers due to focusing on the layout of the problem.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Counting Error', 'question': 'Count the number of stickers in a large collection of 2,345 stickers.', 'mistake': 'Student loses track of the count and incorrectly states there are 2,350 stickers.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the number of stars drawn on a page with 1,000 stars.', 'mistake': 'Student loses track of the count after getting distracted by a noise in the classroom.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Counting Error', 'question': 'Count the total number of apples in 1 million apples, grouped in boxes of 100.', 'mistake': 'Loses track of count after getting overwhelmed, leading to a miscount.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count and write the number of apples in a basket containing 1,243 apples.', 'mistake': 'Forgets to count some apples due to distractions in the classroom.'}
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# {'challenge_type': 'Attention Error', 'question': 'Count the total number of apples: 4321 apples plus 5678 apples.', 'mistake': 'Student loses track of numbers while counting, leading to an incorrect total.'}
# ✅ Dataset generation complete. Saved at: /content/gdrive/My Drive/AIED_Dataset/AI_Model_Eval/student_rag_results_copy.csv
