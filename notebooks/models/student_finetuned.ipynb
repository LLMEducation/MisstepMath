# %%
import openai
import pandas as pd
import random
import time
import os
import json
from collections import Counter


# Set up OpenAI API key
OPENAI_API_KEY = "your-api-key-here"
MODEL_NAME = "your-fine-tuned-model-name"  # Update with your fine-tuned model name
openai.api_key = OPENAI_API_KEY

# Load the train dataset as RAG source
train_dataset_path = "data/train_dataset.json"
with open(train_dataset_path, "r", encoding='utf-8') as f:
    rag_data = json.load(f)

# Convert to DataFrame
rag_df = pd.DataFrame(rag_data)

# Ensure diverse sampling across Grade, Topic, and Sub-topic
def get_balanced_samples(df, num_samples=1000):
    grouped = df.groupby(["Grade", "Topic", "Sub Topic"])
    selected_samples = []

    while len(selected_samples) < num_samples:
        for _, group in grouped:
            if len(selected_samples) >= num_samples:
                break
            sampled_row = group.sample(1)
            selected_samples.append(sampled_row)

    return pd.concat(selected_samples).reset_index(drop=True)

balanced_rag_df = get_balanced_samples(rag_df, 1000)

# Define function to retrieve relevant context from RAG dataset
def retrieve_relevant_context(grade, topic, sub_topic):
    relevant_data = rag_df[(rag_df["Grade"] == grade) & (rag_df["Topic"] == topic) & (rag_df["Sub Topic"] == sub_topic)]
    if not relevant_data.empty:
        return relevant_data.sample(1).to_dict(orient='records')[0]["Problem"]
    return "No relevant example found."

# Generate student responses dynamically
def generate_student_response(grade, topic, sub_topic):
    prompts = [
        f"A student in grade {grade} is struggling with {sub_topic} in {topic}. Generate a student response.",
        f"What is a typical way a student might respond to {sub_topic} in {topic}?",
        f"Simulate a student attempting {sub_topic} in {topic} and making a common mistake."
    ]
    return random.choice(prompts)

# Call the fine-tuned model with RAG context to generate student responses
def get_student_response(prompt, context):
    try:
        response = openai.ChatCompletion.create(
            model=MODEL_NAME,
            messages=[
                {"role": "system", "content": "You are a student responding to a math problem."},
                {"role": "user", "content": f"Context: {context}\n\n{prompt}"}
            ],
            max_tokens=200
        )
        return response["choices"][0]["message"]["content"]
    except Exception as e:
        print("Error generating response:", e)
        return None

# Generate dataset
student_responses = []

for _, row in balanced_rag_df.iterrows():
    grade = row["Grade"]
    topic = row["Topic"]
    sub_topic = row["Sub Topic"]

    student_prompt = generate_student_response(grade, topic, sub_topic)
    context = retrieve_relevant_context(grade, topic, sub_topic)
    student_reply = get_student_response(student_prompt, context)

    if student_reply:
        student_responses.append([grade, topic, sub_topic, student_prompt, context, student_reply])

    # Avoid rate limits
    time.sleep(1)

# Convert to DataFrame
student_responses_df = pd.DataFrame(student_responses, columns=["Grade", "Topic", "Sub-topic", "Student Prompt", "RAG Context", "Student Response"])

# Save dataset
student_responses_df.to_csv("generated_student_responses_rag.csv", index=False)
print("Dataset generation complete. Saved as generated_student_responses_rag.csv")

# %%
# Install OpenAI library (if not installed)
# !pip install openai

# Import necessary libraries
import openai
import json
import pandas as pd
import time
from openai import OpenAI

# Set OpenAI API key (Replace with your key)
secret_key = ''
organization_id = ''
openai.organization = organization_id
openai.api_key = secret_key
os.environ["OPENAI_API_KEY"] = secret_key
client = OpenAI(organization=organization_id)

# Define file paths
train_data_path = "data/train_dataset.json"
formatted_data_path = "data/student_train_dataset.jsonl"

#Uncomment following code to generate fine-tuned model, once model generated, then comment this code and execute further
"""
# Load training dataset
with open(train_data_path, "r", encoding="utf-8") as f:
    train_data = json.load(f)

# Convert dataset to OpenAI fine-tuning format
formatted_data = []

for row in train_data:
    prompt = f"Grade: {row.get('Grade', '')}, Topic: {row.get('Topic', '')}, Sub-topic: {row.get('Sub Topic', '')}"
    student_mistake = row.get('Student\'s Mistake Prompt', '')
    completion = f"#$?#Challenge Type: {row.get('Challenge Type', '')}#$?#Problem: {row.get('Problem', '')}#$?#Student's Mistake: {student_mistake}#$?#"

    if prompt and completion:
        formatted_data.append({
            "messages": [
                {"role": "system", "content": "You are a student making mistakes while solving math problems."},
                {"role": "user", "content": prompt},
                {"role": "assistant", "content": completion}
            ]
        })

# Save formatted data as JSONL
with open(formatted_data_path, "w", encoding="utf-8") as f:
    for entry in formatted_data:
        json.dump(entry, f)
        f.write("\n")

print(f" Formatted dataset saved at: {formatted_data_path}")

# Upload dataset to OpenAI for fine-tuning
response = client.files.create(
    file=open(formatted_data_path, "rb"),
    purpose="fine-tune"
)
print(response)

file_id = "file-QVGgcXbLtwkFDsYHQqH8hB"#response.id
print(f" Dataset uploaded to OpenAI. File ID: {file_id}")

# Start fine-tuning job
fine_tune_response = client.fine_tuning.jobs.create(
    training_file=file_id,
    model="gpt-3.5-turbo"  # Change to "gpt-4-turbo" if needed
)
print(fine_tune_response)
job_id = fine_tune_response.id
print(f"Fine-tuning job started. Job ID: {job_id}")
"""
job_id = "your fine-tuned job id"
# Monitor fine-tuning progress
while True:
    status = client.fine_tuning.jobs.retrieve(job_id)
    status_state = status.status

    print(f"⏳ Fine-tuning status: {status_state}")

    if status_state in ["succeeded", "failed", "cancelled"]:
        print(f" Fine-tuning completed with status: {status_state}")
        break

    time.sleep(60)  # Wait for a minute before checking again

# Get the fine-tuned model name
if status_state == "succeeded":
    fine_tuned_model = status.fine_tuned_model
    print(f"🎉 Fine-tuned student model is ready: {fine_tuned_model}")
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.61.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ⏳ Fine-tuning status: validating_files
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: running
# ⏳ Fine-tuning status: succeeded
# ✅ Fine-tuning completed with status: succeeded
# 🎉 Fine-tuned student model is ready: ft:gpt-3.5-turbo-0125:personal::B2VFnwd2

# %%
print(status)
# Out:
# FineTuningJob(id='ftjob-Y91humBueMVUpPUlFFrJgVkc', created_at=1739934029, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:gpt-3.5-turbo-0125:personal::B2VFnwd2', finished_at=1739936493, hyperparameters=Hyperparameters(batch_size=7, learning_rate_multiplier=2.0, n_epochs=3), model='gpt-3.5-turbo-0125', object='fine_tuning.job', organization_id='org-KaLJlf6HI91T8c0b7uy8XUt2', result_files=['file-NuHhJ4idMwRfPBGhBMrLMC'], seed=1626645714, status='succeeded', trained_tokens=838488, training_file='file-QVGgcXbLtwkFDsYHQqH8hB', validation_file=None, estimated_finish=None, integrations=[], method=Method(dpo=None, supervised=MethodSupervised(hyperparameters=MethodSupervisedHyperparameters(batch_size=7, learning_rate_multiplier=2.0, n_epochs=3)), type='supervised'), user_provided_suffix=None)

# %%
# Install OpenAI library (if not installed)
# !pip install openai pandas

# Import necessary libraries
import openai
import pandas as pd
import random
import time
import json
import os
from openai import OpenAI

FINE_TUNED_MODEL = ""  # Update with your fine-tuned model name

# Define file paths
selected_combinations_path = "data/50_GTS_Combination.csv"
output_csv_path = "data/student_fine_tuned_results.csv"

# Load selected 50 (Grade, Topic, Sub-topic) combinations
selected_combinations = pd.read_csv(selected_combinations_path)

# Function to generate student mistake prompts
def generate_student_mistake(grade, topic, sub_topic):
    prompts = [
        f"A grade {grade} student is struggling with {sub_topic} in {topic}. Generate a common mistake and the problem statement.",
        f"What is a typical error students make in {sub_topic}? Provide a problem where such a mistake happens.",
        f"Create a math problem related to {sub_topic} in {topic} where students usually make errors."
    ]
    start = random.choice(prompts)
    output_format = (
        "Output should be only a valid JSON with the following format: "
        "{\"challenge_type\":\"<challenge type>\", \"question\":\"<math problem>\", \"mistake\":\"<student's mistake>\"}"
    )

    return start + " " + output_format

# Function to call OpenAI fine-tuned student model
def get_math_problem(prompt):
    try:
        response = client.chat.completions.create(
            model=FINE_TUNED_MODEL,
            messages=[
                {"role": "system", "content": "You are a student making mistakes while solving math problems."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=500
        )

        output = response.choices[0].message.content.strip()
        output = output.replace("```json", "").replace("```", "").replace("\\", "")
        if "#$?#" in output:
            output_l = output.split("#$?#")
            challenge_type = output_l[1].split("Challenge Type:")[1]
            question = output_l[2].split("Problem:")[1]
            mistake = output_l[3].split("Student's Mistake:")[1]
        else:
            json_o = json.loads(output)

        return json_o["challenge_type"], json_o["question"], json_o["mistake"]

    except Exception as e:
        print(" Error generating response:", e)
        return None

# Generate dataset
math_data = []

for _, row in selected_combinations.iterrows():
    grade, topic, sub_topic = row["Grade"], row["Topic"], row["Sub Topic"]

    num_samples = 100
    for _ in range(num_samples):
        student_prompt = generate_student_mistake(grade, topic, sub_topic)
        print(f" Generating sample for: {grade}, {topic}, {sub_topic}")

        response = get_math_problem(student_prompt)

        if response:
            print(response)
            challenge_type, question, mistake = response
            math_data.append([grade, topic, sub_topic, challenge_type, question, mistake])

        # Avoid rate limits
        time.sleep(1)

# Convert to DataFrame
math_df = pd.DataFrame(math_data, columns=["Grade", "Topic", "Sub-topic", "Challenge Type", "Question", "Student Mistake"])

# Save dataset to Google Drive
math_df.to_csv(output_csv_path, index=False)

print(f" Dataset generation complete. Saved at: {output_csv_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
# ('Procedural Fraction Error', 'How long is 13 1/4 inches on a ruler with 16 marks per inch?', '- Adding improperly to convert to a single fraction')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural', 'Convert 1 7/8 inches to an improper fraction of an inch.', 'Using mixed numbers instead of decimals for ease of calculation.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure the length to the nearest 1/4 inch.', 'Reading the tape measure at 1/8 inch increments.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural', 'Measure 4 1/4 inches and mark the line.', 'Interpreting the measurement as 4.14 instead of 4.25 inches.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure 2 1/2 inches.', 'Using improper notation for 2 1/2 as 2.5 or 2 5/10.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Misinterpretation', 'Measure 1/4 inch on the ruler', 'Adding several small divisions instead of using 1/4 mark')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual Error', 'Find 7/16 on a ruler and measure.', 'Confusing 1/16 divisions with 1/8 divisions.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure the length to the nearest 1/4 inch.', 'Rounds 3/16 inch to the nearest 1/4 inch as 1/4 inch.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Convert 2 1/2 inches to a decimal.', '2 1/2 is not the same as 2.5')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Reading Fractions on a Ruler', 'What measurements are marked between 0 and 1 inch?', 'Mistaking 1/16 inch for 1/8 inch.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ❌ Error generating response: Expecting ',' delimiter: line 1 column 112 (char 111)
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural', 'Convert 3/8 inch to decimal.', 'Student reads 3/8 as 3.8 inches.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural', 'Measure 5/8 inch using a ruler.', 'Assuming 5/8 is always the same length regardless of the units.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural', 'What is 1 3/8 inches + 2 5/8 inches?', 'Misconverting 1 3/8 as 1.38 inches.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure 1/8 inch accurately on the ruler.', 'Adding the wrong fractions when measuring.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Convert 1 1/2 inches to an improper fraction.', 'Not recognizing that 1 1/2 = 3/2 inches')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual', 'Identify 0, 1/4, 1/2, 3/4 on the ruler.', 'Reading 1/4 inch as 1 inch by confusing fractions on the ruler.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual Error', 'Measure 5 inches using the ruler and mark 1/8 inch increments.', '# Dividing the inch into 1/8 clearly is shown.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'What is 3 1/2 inches + 2 3/4 inches?', 'Taking 3 1/2 as 31/2 and adding instead of 7/4 + 11/4.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Fractions of an Inch', 'What is 3/4 inch + 1/8 inch?', 'Misaligning the ruler to measure 1/8 inch accurately.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual', 'What is the length at 2 1/2 inches?', 'Adding 2 and 1/2 instead of reading the length at 2 1/2 inches.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Precision Measurement', 'If a paper is 0.045 inches thick, how thick is a stack of 20 papers?', '#ERROR: Undefined conversion to find total thickness.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Fractions in Measurement', 'What fraction of an inch is 5/8 inch on a ruler?', 'Not realizing that 5/8 inch is just over half an inch and less than an inch.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual Error', 'Measure 1/4 inch on a ruler.', 'Reading 1/2 inch instead of 1/4 inch.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure the length to the nearest 1/16 inch.', 'Rounding down instead of up when needed.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Convert 3/4 inch to decimal.', 'Mixing up the numerator and the denominator resulting in 4/3 instead of 3/4.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Convert 1/4 inch to decimals.', 'Dividing by 1/2 instead of 1/4.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure 7/8 inch on a ruler starting from 0.', 'Ignoring the 1/8 subdivision and stopping at the nearest whole number.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Fractions of an Inch', 'Convert 5/8 inch to decimal.', 'Student multiplies 5 by 8 instead of dividing.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural', 'Convert 5/16 inch to a decimal.', '5/16 inch is 0.312 inch, not 0.625 inch.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'What is 3 and 5/8 inches represented as a decimal?', 'Converting mixed number to decimal by treating it as a sum instead of a single value.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conversion Challenge', 'Convert 1 inch to eighths.', 'Reading 1 1/8 instead of 1 0/8 (1).')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure 3/8 inch on the ruler.', 'Confusing 3/8 with 5/8 leading to incorrect measurement.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Ruler Measurement Error', 'Measure the length to the nearest 1/16 inch.', "Misaligning the measurement at the 1/4 inch mark and assuming that's a full inch.")
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural', 'Convert 1 3/8 inches to an improper fraction.', 'Student uses 1/3 as part of the conversion.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual Error', 'What is 2 1/2 inches + 3/4 inches?', 'Student adds the whole numbers and fractions separately.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual Error', 'Which is longer: 1/2 inch or 1/4 inch?', '<1/4 inch is longer because 2/4 is bigger than 1/4 due to the larger denominator>')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conversion', 'Convert 7/16 inches to decimal.', 'Adding instead of converting the fraction.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Conversion', 'Convert 1 1/2 inches to an improper fraction of an inch.', 'Adding the whole number of inches to the fraction part without proper conversion.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual Error', 'Explain the difference between 1/4 inch and 1/8 inch.', 'Thinking 1/4 inch is the same as 1/8 inch since they both have an 8 in the denominator.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Find 3 1/8 inches on the ruler.', 'Mistaking 1/4 inch for 1/8 inch, leading to incorrect measurement.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Convert 3 1/2 inches to a single fraction.', 'Mixing whole number with the fractional part leading to confusion.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Fractions', 'What is 1 3/8 inches + 1 4/8 inches?', '1 3/8 in + 1 4/8 in = 2 1/11 in')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Misinterpretation', 'Read the measurement 1 3/4 inches.', 'Reading as 1 4/4 inches.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure 2 1/2 inches from the left edge of the paper and make a mark.', 'Counting 1/16 marks beyond 2 1/2 inches.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural', 'Convert 1/2 inch to the nearest fraction of a fourth of an inch.', 'Using 1/4 inch directly instead of recognizing the relationship.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure the line to the nearest 1/4 inch:', 'Rounding 1/8 inch to 1/4 inch.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Units & Measurement', 'Convert 3/8 inch to decimal inches.', 'Student reads 3/8 as 3.8 inches')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'How many 1/16 inch marks are visible as 1/8 inch on the ruler?', 'Counting 4 marks instead of 2.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Fraction misinterpretation', 'Measure 7/8 inch on the ruler accurately.', 'Counting the 8th marks as 16th marks, doubling the 7 to 14.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual', 'Convert 3/8 inch to its decimal equivalent.', 'Student multiplies 3 and 8 instead of dividing.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conversion', 'Convert 2 1/4 inches to centimeters.', 'Rounding the fraction incorrectly.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure to the nearest 1/8 inch.', 'Estimating 1/8 inch but measuring 1/4 inch instead.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure 7/8 inches on the ruler.', 'Reading the wrong side of the tick mark, confusing it with 1/8 inch.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure 5/8 inch on the ruler.', 'Ignoring smaller divisions and stopping at the nearest whole number.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure 1 and 11/16 inches.', 'Incorrectly reading the tape measure as 1 and 6/16 inches.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Proportional Reasoning', 'If a bolt is 1 and 5/8 inch, how many 3/8-inch washers can fit in 4 inches?', "<student's mistake>")
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Fractional Error', 'What is 2 5/8 inches + 3 3/8 inches?', "<student's mistake>")
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Fractions of an Inch', 'A tape is marked at eighths of an inch. What is 3/8 inch + 2/8 inch?', 'Misreading the tape causing errors in adding fractions')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural', 'In inches, what is 3/8 + 1/4?', 'Reading the ruler inaccurately for 1/4 inch')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Measurement in fractions', 'Measure 1 and 5/8 inches', 'Misinterpreting the 1/8 inch mark as 1/4 inch')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural', 'Add 3/16 inch and 5/32 inch.', 'Reading marks as 1/8 instead of their true value.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual', 'Identify 1/8 inch on the ruler.', '#error: Incorrectly identifies a different mark as 1/8 inch.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual Misunderstanding', 'What is the difference between 3/4 inch and 1/2 inch?', 'Student believes the difference is 1/4 inch because they are using the denominators.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Where does the 4/8 inch mark fall on the ruler?', 'A child may think 2/4 is greater because 2 is greater than 4, leading to confusion.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Fractional Inch Measurement', 'What is the sum of 2 1/4 inches and 3 3/8 inches?', 'Adding whole numbers first instead of the fractions correctly.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural', 'Convert 2 5/8 inches to an improper fraction of an inch.', 'Considering the whole number as part of the fraction and writing 2 5/8 as 2 8/8 inches.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual Error', 'What is the difference between 3 1/4 and 3 1/8 inches?', 'Student adds the fractions instead of subtracting.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conversion', 'Convert 2 5/8 inches to an improper fraction of an inch.', 'Misinterpreting the mixed fraction as a multiplication of 2 by 5/8.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural', 'Convert 1 3/8 inches to an improper fraction of an inch.', 'Adding the whole number part to the fraction part.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Convert 1 1/4 inches to the nearest 1/8 inch.', 'Rounding without considering the fraction value.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conversion of 3/8 inch to decimal', 'What is 3/8 inch in decimal?', 'Student converts 3 and 8 separately to decimals.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Fractions of an Inch', 'Convert 1/4 inch to the nearest 1/32 inch.', 'Student assumes 1/4 inch equals 8/32 inch.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Problem Solving', 'If a space is 2 1/2 inches wide, can a 2 1/4 inch object fit?', '#REF!')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Convert 5/8 inch to decimal.', "Reading 5/8 as '5 divided by 8' instead of '5 eighths'.")
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'What is 1/4 inch + 1/8 inch?', 'Adding numerators without a common denominator.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Convert 5/8 inch to decimal.', 'Dividing 5 by 8 instead of 5/8.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conversion Error', 'Convert 5/8 inches to decimal.', 'Misreading or misplacing the decimal point.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Fraction Conversion', 'Convert 3 5/8 inches to a mixed fraction of inches.', 'Mixing up the whole number with the fraction during conversion.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conversion', 'Convert 1 1/2 inches to an improper fraction of an inch.', 'Mixing up the whole number and the numerator in the improper fraction.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'What is 0.25 inches in fraction form?', 'Confusing between eighths and quarters, representing 0.25 inches as 0.2 inches instead of 1/4 inch.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'What is 4/8 inch in inches?', 'Confusing 4/8 with 1/2, resulting in 1/2 inch.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conversion Error', 'Measure 3/8 inch on a ruler.', 'Confusing 1/8 inch intervals with 1/16 inch intervals.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Fraction Addition', 'Add 1/8 inch + 1/4 inch.', 'Misadding fractions with different denominators.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual Error', 'Estimate the length to the nearest 1/4 inch.', 'Assuming any mark is a quarter without actual measurement.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'What is the length shown as a fraction of an inch on the ruler?', 'Estimating 5/8 inch as 3/4 inch due to visual alignment.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Misinterpretation', 'Identify the measurement on the ruler: 1/8 inch', 'Thinking 1/8 is smaller than 1/4')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual', 'Estimate the length to the nearest inch.', 'Student estimates a fraction of an inch instead.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure 3/4 inch along a ruler.', 'Misinterpretation of the fraction leading to incorrect measurement.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Add 2 and 3/16 inches to 3 and 9/16 inches.', 'Incorrectly converting 9/16 to higher whole number value.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual', 'Convert 1/2 inch to the nearest fraction of an inch.', 'Identifying 1/2 inch as 1/4 inch.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Estimation', 'Estimate the length to the nearest inch.', 'Mistaking 2 1/2 inches as 2 inches.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Fraction Conversion', 'Convert 3/16 inch to decimal.', 'Student converts 3/16 to 0.48 instead of 0.1875.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Practical Problem', 'Measure the length to the nearest 1/16 inch.', 'Confusing between 1/8 and 1/16 marks.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure the length to the nearest 1/4 inch.', 'Rounds 2/4 to 1/2 instead of 1/4')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Convert 1 3/8 inches to an improper fraction.', 'Saying 1 3/8 is less than 1.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Convert 1 3/4 inches to an improper fraction of an inch.', 'Reading 3/4 inch as 3.4 inches.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Procedural Error', 'Measure 3/8 inch on a ruler.', 'Aligning the mark at 3/8 instead of at 7/8.')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Conceptual Error', 'Convert 1 1/2 inches to an improper fraction of an inch.', '1 1/2 inches = 1 2/6 inches')
# 📝 Generating sample for: K3, Measurement, measuring lengths (including in fractions of an inch)
# ('Practical Application', 'You need a 6 1/4-inch board to repair a cabinet. How long should you cut a 9 7/8-inch board to fit?', 'Student confuses between different units of measurement.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'How does the Pythagorean Theorem apply to a non-right angled triangle?', "Student's Mistake")
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'Given a right triangle with sides 6 and 8, what can you say about the third side?', 'Assuming all triangles are right triangles based on the Pythagorean Theorem only.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Misunderstanding', 'What will happen if two sides of a triangle are perpendicular?', 'Implies the triangle is automatically a right triangle.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Misinterpretation', 'Find the hypotenuse of a right triangle with legs of 4 units and 3 units.', 'Assuming every triangle with sides 3, 4, and 5 units is a right triangle due to their Pythagorean triple relationship.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'A ladder is leaning against a wall. If the base is 6 meters from the wall and the ladder is 10 meters, find the height it reaches.', 'Interchanging legs and hypotenuse thinking height is 6 or 10 instead of the other.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Find the hypotenuse if a = 10, b = 24.', 'Assuming c = a + b.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a right triangle with sides 12cm, 5cm, what is the length of the hypotenuse?', 'Using Pythagoras, but making a calculation error.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Find the hypotenuse of a right triangle with legs 5 cm and 12 cm.', 'Assuming the longest side is always the hypotenuse.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Algebraic Manipulation', 'Solve for c if a = 4, b = 3 in c^2 = a^2 + b^2', 'Assuming a = 3 and b = 4 instead of the provided values.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'A ladder leans against a wall, forming a right triangle. If the ladder is 15 ft long and the base is 9 ft, what is the vertical height it reaches?', 'Assuming the ladder is the hypotenuse without justification.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'Find the hypotenuse if a = 3 and b = 4.', 'Only using one form of a^2 + b^2 = c^2.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a right triangle, if a² + b² = c², what does each side represent?', 'Student confuses which side is the hypotenuse.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ❌ Error generating response: Expecting ',' delimiter: line 1 column 114 (char 113)
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'A right triangle has legs of 5 cm and 12 cm. Find the hypotenuse.', 'Assigning 5 cm as the hypotenuse and using the wrong formula.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Misinterpretation', 'In a right triangle with legs 4 units and 7 units, what is the distance from the right angle to the hypotenuse?', 'Adding or multiplying the legs.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Misunderstanding', 'If given sides 2, 3, and 4, is the triangle a right triangle?', 'Ignoring the correct Pythagorean Theorem application due to side order.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'If a triangle is a right triangle, what relationship do its sides have?', 'Student thinks the theorem applies to all triangles.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Procedural Error', 'In a right triangle, a = 8, c = 10. Find b.', 'Using a^2 + b^2 = c^2 without rearranging for b^2.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'If a triangle has sides 3, 4, and 5, what type of triangle is it?', "<student's mistake>")
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'If a triangle has sides 3, 4, and 5, is it a right triangle?', 'Assuming all triangles with sides in ratio 3:4:5 are right triangles.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Find the hypotenuse of a right triangle with legs 5cm and 12cm.', 'Assuming the longest side is always the hypotenuse.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Identify a situation where the Pythagorean Theorem is not applicable.', 'Student assumes the theorem is universally valid for all triangles.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'A ladder is leaning against a wall. Given the ladder is 5m, and the bottom is 2m from the wall, find the height reached.', 'Assuming the ladder does not follow a straight line when leaning.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Given a triangle with sides 6 cm, 8 cm, and 10 cm, find the angle opposite the side of length 8 cm.', 'Assuming an angle is 90 degrees without calculations.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Procedural Error', 'Find the hypotenuse of a right triangle with legs 3 cm and 4 cm.', 'Assuming the longest side is the hypotenuse without confirming.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a right triangle, if a=5 and b=12, what can we say about the triangle?', 'Assuming the triangle is equilateral.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Using Pythagorean Theorem in any triangle', 'Assuming all triangles are right-angled when applying the theorem')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'What assumption is made in a right triangle to apply the Pythagorean theorem?', 'Assuming a triangle is right-angled without verification.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'A ladder leans against a wall forming a right-angled triangle. If the ladder is 10m and the height is 6m, what is the ground distance covered?', 'Making the ladder the hypotenuse instead of matching sides.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a right-angled triangle, if a = 3, b = 4, find c.', 'Assuming c = 12 by adding a and b.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Using Pythagorean Theorem, what if a triangle has two right angles?', 'Assuming a triangle can have 2 right angles and still use Pythagorean Theorem.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'Given a triangle with sides 3, 4, and 5, is it a right triangle according to the Pythagorean Theorem?', 'Misunderstanding when the theorem applies.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Misunderstanding', 'In a right triangle, if a = 12 and b = 5, what does c represent?', 'c is the hypotenuse and not the side opposite the right angle.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'If a = 5, b = 12, find the length of the hypotenuse.', 'Assuming a = 12 and b = 5 leading to incorrect results.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a 3-4-5 right triangle, what is the length of the hypotenuse?', 'Misreading the sides and finding the wrong length.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'A ladder leans against a wall forming a right triangle with the ground. Find the angle of elevation if the ladder is 10 m long and the height it reaches is 6 m.', 'Assuming the Pythagorean Theorem can be used to find the angle.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'Can any three given side lengths form a right triangle?', 'Assuming any combination of side lengths will work.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Procedural Error', "If a ladder reaches 15 ft up a wall seeing over a 9 ft fence, what is the ladder's total length resting on the ground?", 'Rounding off intermediary values as approximate')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'If a triangle has sides 9, 12, and 15, is it a right triangle?', 'Assuming a triangle with sides in right triangle proportion is always a right triangle.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'If a triangle is a right triangle, what should be true according to the Pythagorean Theorem?', "Student's Mistake: Assuming the Pythagorean Theorem is applicable to all triangles, not just right triangles.")
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'Find the unknown side of a right triangle with a = 8, b = 6.', 'Equating c = 10 instead of using c^2 = a^2 + b^2.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Given a triangle with sides 3, 4, and 5, is it a right triangle?', 'Assuming all triangles with sides in a 3:4:5 ratio are right triangles without further checks.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Mistake', 'Find the hypotenuse of a triangle with legs 6cm and 8cm.', 'Adding 6 and 8 instead of squaring them.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Procedural Error', 'Find the distance between two points: A(3, 4) and B(7, 1).', 'Confusing the x and y coordinates in the formula.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'A right triangle has legs of 3 units and 4 units. Find the hypotenuse.', 'Thinking 3 and 4 are the hypotenuse and making a wrong substitution.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Misunderstanding', 'What does each side of a right triangle represent in a^2 + b^2 = c^2?', 'Student mistakenly thinks a or b equals the hypotenuse.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Procedural Error', 'Calculate the hypotenuse given leg lengths 3 units and 4 units.', 'Rounding intermediate steps instead of the final answer.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Find the distance between two points (2, 3) and (7, 5).', 'Mistaking the magnitude of vectors for Pythagorean application.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Misinterpretation', 'Find the hypotenuse if one leg is 5 and the other is 12.', 'Misunderstanding the input values for a and b in a^2 + b^2 = c^2.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Misunderstanding', 'Find the diagonal of a rectangle with side lengths 3 and 4 units.', 'Assuming any two sides are a right angle to use the theorem.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'If the hypotenuse is 10 and one leg is 6, what could the other leg be?', '#4#rounding and summing squared lengths')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'A ladder reaches 13 ft up a wall and rests on a ledge 5 ft above the ground. How far is the base of the ladder from the wall?', 'Assuming the ladder is directly above the ledge, leading to wrong application of the theorem.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a right triangle, the square of the hypotenuse is 25 units. What is the length of each leg?', 'Mistaking the hypotenuse as a leg and finding non-existent other leg.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Misunderstanding', 'Is it possible to have a right-angled triangle with all sides of equal length?', 'Assuming all equilateral triangles are right-angled.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'Find the unknown side in a right triangle with a = 6, b = 8, c = ?', 'Mixing up the sides and using 6 as hypotenuse, 8 as other side.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'When does a triangle satisfy the Pythagorean Theorem?', "Student's mistake")
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'A ladder leaning against a wall forms a right triangle with the ground. If the ladder is 10 meters long and the base is 6 meters, what is the height it reaches?', "<student's mistake>")
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', "A ladder leaning on a wall forms a right angle. What will happen to the ladder's height if the angle decreases?", "Assuming the ladder's height increases.")
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'A ladder 10m long leans against a wall. How far up the wall does it reach?', "Assuming the ladder's length is the hypotenuse without considering the ground.")
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'If a triangle is isosceles, how are the sides related in the Pythagorean Theorem?', 'Student confuses side lengths in the equation if sides are not labeled correctly.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Misinterpretation', 'A ladder leans against a wall forming a right triangle. If the ladder is 10m tall and the wall is 8m long, find the distance from the base of the ladder to the wall.', 'Assuming the ladder is the hypotenuse and calculating the adjacent side.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'If side c=5, calculate the length of side b if a=3.', 'Using the theorem incorrectly as a^2 + c^2 = b^2.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Find the hypotenuse of a right triangle with legs 2cm, 3cm.', 'Using the theorem to find an incorrect side.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'If a ladder is leaning against a wall with a length of 5m and reaches 5m up the wall, how far from the wall does the ladder reach?', 'Assuming the ladder is not the hypotenuse of a right triangle.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a triangle, if angle A = 90 degrees, what does that mean for side AB and side AC?', 'Assuming AB is the hypotenuse because it is written across the right angle.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Misinterpretation', 'In a right triangle with legs of 3 cm and 4 cm, what is the hypotenuse?', 'Using the theorem incorrectly due to triangle orientation.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a right triangle, if a+b = 10 and ab = 24, find the hypotenuse.', 'Assuming the other two sides are a and b instead of c.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'If the hypotenuse is 10 units and a leg is 6 units, what is the length of the other leg?', "Ignoring that 6 is a leg and assuming it's the hypotenuse.")
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'Given right triangle ABC, find the length of side AC if AB = 6 cm and BC = 8 cm.', 'Assuming sides AB and BC are the legs and adding them instead of squaring and adding.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a triangle with sides 4, 7, and 8 units, is it a right triangle?', 'Assuming all triangles with these side lengths are right triangles.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Procedural Error', 'Find the length of Diagonal D in a rectangle with sides 3 and 4.', 'Labeling longer side as hypotenuse.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'If a ladder is 10 feet away from the wall and reaches 12 feet up, how long is the ladder?', 'Misuse of d = 10, a = 12, instead of c^2 = a^2 + b^2.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'If a right triangle has sides of 3 cm and 4 cm, what is its area?', 'Confusing Pythagorean Theorem with finding area.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Algebraic Error', 'Find the length of the hypotenuse in a right triangle with legs of x+2 and x-1.', 'Student adds the legs instead of squaring them.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'Calculate the hypotenuse if legs are 3 cm and 4 cm.', 'Thinking Pythagorean Theorem works for non-right-angled triangles.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a right triangle with legs 6 units and 8 units, what is the hypotenuse?', 'Student assumes an arbitrary-length side is the hypotenuse.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a right triangle, a = 5 cm, b = 12 cm. Find the hypotenuse.', 'Thinking 5^2 + 12^2 equals 17^2.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a right triangle, the hypotenuse is doubled. By what factor does the area change?', 'Assuming the area is doubled without considering the change in side lengths.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'If a right triangle has legs of 3 units and 4 units, what is the hypotenuse length?', '#*$5^2 = 25$, not $3^2 + 4^2 = 5^2$. Typographical error.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Misinterpretation', 'For which triangle does Pythagorean Theorem not apply?', 'Pythagorean Theorem can be used for any right-angled triangle.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Procedural Error', 'Calculate the hypotenuse if a = 6 and b = 8.', 'Not squaring the lengths before adding.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'A triangle has sides 6, 8, and ? . What is the length of the missing side?', '<Enter mistake here>')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'You have a triangle with sides 5 cm, 12 cm, and unknown. Calculate the third side.', 'Assuming the right triangle without verifying angles.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'If a triangle is a right triangle, what does the Pythagorean Theorem state?', 'Student assuming that the Pythagorean Theorem applies to all triangles.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a right triangle, what should you do when given an angle?', 'Assuming that Pythagorean Theorem can be used directly without adjustment.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Apply Pythagorean Theorem to find the hypotenuse of a right triangle with legs 5 cm and 12 cm.', 'Confusing leg and the hypotenuse.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'In a triangle with sides 7, 24, and 25, what can we tell about the angles?', 'Student may assume it is always a right triangle.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a right-angled triangle with legs 3 cm and 4 cm, find the length of the hypotenuse.', 'Interchanging the roles of legs and hypotenuse.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'If two sides of a triangle are 4 units and 7 units, what can you say about the third side?', 'Assuming the third side must be the hypotenuse.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'If a triangle has sides 3, 4, and 5, is it a right triangle?', 'Thinking all triangles with integer sides are right triangles.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Find the hypotenuse of a right triangle with legs 4 cm and 3 cm.', 'Mistaking the sum or difference of squares for another formula.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a right-angled triangle, what does the hypotenuse represent?', 'Student incorrectly identifies the hypotenuse as the side opposite the right angle.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'If a triangle is 5-12-13, what can you infer about it?', 'Mistakenly thinking all triangles with sides 5, 12, 13 are right triangles.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Is a triangle with sides 5, 12, 13 a right triangle?', 'Assuming any triangle with these sides is right-angled.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'In a right-angled triangle, if a and b are interchanged, what happens to c?', 'Assuming c changes if a and b switch places.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'If two sides of a triangle are 9 units and 12 units, can the third side be 11 units?', 'Assuming any combination of side lengths will form a right triangle.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Find the length of the hypotenuse in a triangle with legs of 5 cm and 12 cm.', 'Assuming 12 cm is the hypotenuse.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual', 'Apply the Pythagorean Theorem to solve for c if a = 12 and b = 5.', 'Adding a and b instead of squaring them.')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'In a right triangle, if a = 5 cm and b = 12 cm, find the hypotenuse.', 'Student uses a+b instead of a^2 + b^2')
# 📝 Generating sample for: K8, Geometry, Applying the Pythagorean Theorem
# ('Conceptual Error', 'Find the missing side: a = 4, b = 3, c = ?', 'Asking for c rather than finding the missing side using Pythagorean theorem.')
# 📝 Generating sample for: K6, Geometry, Calculating area, surface area, and volume of various shapes
# ('Surface Area', 'Calculate the surface area of a cube with side 5 cm.', '5 * 5 * 5 = 125 cm^2')
# 📝 Generating sample for: K6, Geometry, Calculating area, surface area, and volume of various shapes
# ('Calculation of Volume', 'What is the volume of a sphere with radius 4 cm?', 'Student forgets to divide the diameter by 2 to get the correct radius.')
# 📝 Generating sample for: K6, Geometry, Calculating area, surface area, and volume of various shapes
# ('Area/Surface Area/Volume', 'Calculate the surface area of a cylinder with radius 2 cm and height 5 cm.', 'Treating the cylinder as a rectangular prism.')
# 📝 Generating sample for: K6, Geometry, Calculating area, surface area, and volume of various shapes
# ('Area of composite shapes', 'Calculate the area of this composite shape: two intersecting rectangles', 'Student only adds the two separate rectangle areas')
# 📝 Generating sample for: K6, Geometry, Calculating area, surface area, and volume of various shapes
# ('Surface Area of a Composite Shape', 'Calculate the surface area of a composite shape made of a cube and a pyramid sharing a base.', "Assuming the pyramid's triangular faces add to the cube's faces directly without adjustment.")
# 📝 Generating sample for: K6, Geometry, Calculating area, surface area, and volume of various shapes
# ('Area Calculation', 'Find the area of a rectangle with length 5 cm and width 3 cm.', 'Adding length and width instead of multiplying.')
# 📝 Generating sample for: K6, Geometry, Calculating area, surface area, and volume of various shapes
# ('Volume Calculation', 'Find the volume of a sphere with radius 5 cm.', 'Ignoring the 4/3 factor in the volume formula.')
# 📝 Generating sample for: K6, Geometry, Calculating area, surface area, and volume of various shapes
# ('Area of Composite Shapes', 'Calculate the area of a figure composed of a rectangle and a semicircle with diameter 7 cm.', 'Adding areas of rectangle and semicircle without adjusting for overlap.')
# 📝 Generating sample for: K6, Geometry, Calculating area, surface area, and volume of various shapes
# ('Area of a composite shape', 'Calculate the area of a shape composed of a rectangle and a semicircle.', 'Adding the areas instead of subtracting the overlapping part.')
# 📝 Generating sample for: K6, Geometry, Calculating area, surface area, and volume of various shapes
# ('Volume Calculations', 'Calculate the volume of a cone with radius 3 cm and height 4 cm.', 'Adding radius and height instead of multiplying to get volume.')
# 📝 Generating sample for: K6, Geometry, Calculating area, surface area, and volume of various shapes
# ('Area', 'What is the area of a rectangular garden with length 10m and width 5m?', "<student's mistake>")
# 📝 Generating sample for: K6, Geometry, Calculating area, surface area, and volume of various shapes
# ('Volume of a Cylinder', 'A cylinder has a base radius of 2 cm and height 5 cm. Find its volume.', 'Misusing the conversion factor, for example, assuming 1 cm equals 1 m instead of 0.01 m.')
# ...
# ('Numbers and Operations in Base Ten', 'Estimate the sum of 3,456,789 and 2,345,678.', 'Student adds the numbers directly without estimating.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Conceptual Error', 'Round 8,763,421 to the nearest million', "Thinking it's 12,000,000 instead of 9,000,000")
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'What is the value of 4 in 6,432,109?', 'Student reads 4 as 4 million instead of 4 thousand.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Conceptual', 'What comes after 1,000,000?', 'Not recognizing 1,000,001 as the next number.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations', 'Estimate the sum of 5,678,901 and 2,345,678.', 'Ignore the millions place, then add.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations in Base Ten', 'Add 7,890,123 and 4,567,890.', '7,890,123 + 4,567,890 = 12,457,013 (Incorrect arrangement of digits)')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value Understanding', 'Round 4,567,891 to the nearest million.', 'Adding a space after 4 and grouping numbers incorrectly.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Large Number Addition', 'Add 4,567,890 + 1,234,567.', 'Ignoring the carry from 0 + 7.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Estimation', 'Estimate the sum of 3,450,000 and 2,550,000.', 'The mistake of rounding the numbers differently.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations in Base Ten', 'Round 6,789,123 to the nearest million', 'Student neglects the 7 in millions place and rounds to 6 million.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ❌ Error generating response: Expecting ',' delimiter: line 1 column 117 (char 116)
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numerical Misconception', 'Which is larger: 6,000,000 or 6,300,000?', 'Mixing up place values.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations', 'Add 2,345,678 and 1,111,111.', 'Reading 1,111,111 as 1,112,111.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'What is the value of 9 in 7,895,612?', 'Student thinks value depends on the digit itself.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'What is the value of 8 in 4,583,219?', "Student's mistaking the value of the digit.")
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'What is 2,456,789 divided by 100?', 'Reading the result as 245,678.9 instead of 24,567.89')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations in Base Ten', 'Round 6,789,123 to the nearest hundred thousand.', 'Student adding instead of rounding.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations', 'Round 8,345,678 to the nearest million.', '8,345,678 rounded to 9,000,000')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Arithmetic', 'Add 6,789,012 + 3,456,789', 'Student drops a 9 by accident.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Whole Number Sense', 'What is 7,000,000 + 300,000 + 40,000 + 5000 + 600 + 70 + 8?', 'Treating zeros as placeholders, not as part of the number.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Large Number Addition', '123,456,789 + 987,654,321', 'Not aligning numbers correctly to add units, tens, etc.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations in Base Ten', 'Add 356,789 and 500,234.', 'Transposing digits while adding.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Arithmetic', 'Add 3,200,000 and 4,500,000.', 'Using commas inconsistently or omitting them, leading to errors.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Large Number Arithmetic', 'Add 123,456,789 and 987,654,321.', 'Appending commas without considering correct placement.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations in Base Ten', 'Add 9,999,999 and 1,000,000.', 'Student may forget to carry over the 1 to the millions place.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'Identify the value of 5 in 8,569,421', 'Thinking 5 is in the thousands place')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations', 'What is the value of the digit 5 in 5,432,198?', 'The value is 500,000.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Misinterpretation', 'Which number is bigger: 5,000,000 or 500,000?', 'Student considers 5,000,000 to be smaller than 500,000.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations in Base Ten', 'If 1 million is 1,000 thousands, how many thousands are in 10 million?', 'Student multiplies 10 by 1,000 instead of by 1,000 thousands.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numerical Error', 'Round 4,567,890 to the nearest million.', 'Ignoring the 5 as not impacting rounding.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numerical Estimation', 'Estimate the sum of 12,345,678 and 9,876,543.', "<student's mistake>")
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Approximation', 'Estimate the sum of 1,234,567 and 8,765,432', 'Student confuses the order and sums inaccurately.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations', 'Which is larger: 5,678,912 or 6,789,215?', 'Student may think 5,678,912 is larger due to the increasing pattern.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Arithmetic', 'Add 6,789,012 and 3,210,987.', 'Considering the sum as 9,000,000 instead of 10,000,000.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value Error', 'What is the value of 5 in 5,678,912?', 'Student thinks the 5 is in the millions place.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Large Number Addition', '123,456,789 + 987,654,321', 'Ignoring the correct position of digits during addition')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Misinterpretation Error', 'What is 5,000,000 + 300,000 + 20,000 + 100?', 'Student might read the commas as decimal points and add it as 5.3 million instead of 5,320,100.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Whole Number Operation', 'Add 345,678 and 123,456.', 'Transposing digits while calculating the sum.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Arithmetic', '1500000 + 2000000 = ?', 'Thinking the answer is 350 instead of 3500000')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'Is 4,567,890 divided by 100 equal to 45,678.9?', 'Not realizing the decimal should move two places to the left after dividing by 100.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations', 'Round 5,678,912 to the nearest million.', 'Ignoring the 8 in the hundreds place when deciding whether to round up.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations', 'What is the sum of 5,678,901 and 1,234,567?', 'Assuming the sum will be in the same format as the numbers.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'What is the value of 7 in 7,654,321?', "Student's mistake")
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Fractions and Decimals', 'Add 5.123 and 6.789.', 'Rounding incorrectly before adding.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'What is the value of 3 in 4,567,890?', 'Student thinks 3 is in hundred thousands.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations', 'Multiply 123,456 by 7,890', 'Switching digits while copying the numbers')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'What is the value of 6 in 6,789,012?', 'Value of 6 is read as 6 instead of 6 million.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'What is the value of 5 in 5,678,912?', '<Student may say 5 million instead of 5>')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations in Base Ten', 'What is 1,000,000 + 2,000,000?', 'Student adds the millions place as 3.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Arithmetic', 'Add 5,432,109 + 6,543,210', 'Adding units, tens, etc. incorrectly')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value Error', 'Write 3,000,000 in expanded form.', '12,345,678: 1 ten thousand, 2 thousand, 3 hundred, 6, 7, 8')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'What is the value of 5 in 6,543,210?', 'The value is 50,000.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Symbolic Manipulation', 'Calculate 7000000 + 8000000', 'Mixing up place values.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Estimation', 'Estimate the sum of 3,412,567 and 2,345,678.', '<span>Ignoring digits after the millions place.</span>')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Whole Number Operations', 'Calculate 345,678 + 123,456.', 'Confusing group of numbers in the operation.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'Which place is the 3 in 3,456,789?', 'Student may confuse and place the 3 in the hundred thousands place instead of the millions place.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'What is 8,000,000 + 200,000 + 5,000 + 300?', 'Rounding each number instead of treating them as whole numbers.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Arithmetic', 'Add 1234567 and 2345678.', 'Assuming the carry from the previous addition.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'Write 3,456,789 in words.', 'Student reads it as three four five six seven eight nine.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations', 'Estimate the sum of 4,567,890 and 1,234,567.', "<student's mistake>")
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Magnitude', 'Which is greater: 6,789,123 or 6,891,234?', 'Student struggles to compare large numbers accurately.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations in Base Ten', 'Multiply 400,000 by 5.', 'Adding instead of multiplying place value digits.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Large Number Multiplication', 'Multiply 3,000,000 by 4,000,000', 'Comma placement error due to confusion between million and thousand')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Arithmetic', 'Add 5,678,912 and 3,456,789.', 'Student drops the zero when copying 3,456,789 as 3,456,78.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Large Number Conceptual Error', 'What is the difference between 5,000,000 and 500,000?', 'Student thinks the difference is 450,000 because they subtract 5 - 5 first.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations: Place Value', 'What is the value of 5 in 5,000,000?', "Student thinks it's 500,000")
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value', 'Write 7000000 in expanded form.', 'Student writes 7000000 as 7000 + 0000.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations: Whole Numbers in the Millions', 'What is 5000000 + 3000000 + 2000000 equal to?', 'Using commas inconsistently leading to confusion.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Place Value Misinterpretation', 'What is the value of 3 in 3,456,789?', 'Thinking the value is 30,000 instead of 3,000,000')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Arithmetic', 'Multiply 4,500,000 by 3', 'Ignoring the correct number of zeroes in the result')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Procedural Error', 'Round 6,789,012 to the nearest million', 'Dividing instead of using place value to round')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations: Whole Numbers (Up to Millions)', 'Which is larger: 5,789,000 or 5,798,000?', "student's mistake")
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Large Number Misinterpretation', 'Round 4,567,890 to the nearest million.', 'Student incorrectly rounds down to 4 million.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations in Base Ten', 'Convert 9000000 to scientific notation.', '9000000 = 9 * 10^6. The mistake is to write it as 9 * 10^7.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations', 'Round 5,678,912 to the nearest thousand.', "<student's mistake>")
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations: Whole Numbers', 'What is 10^6 - 999999?', 'Taking 10^6 as 16.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numbers and Operations in Base Ten', 'What is the sum of 5,678,912 and 3,456,789?', 'Student adds the numbers in each place instead of combining the whole numbers.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Number Sense', 'What comes next in the sequence: 1,000,000; 2,000,000; 3,000,000?', '999,999 being chosen as the next number.')
# 📝 Generating sample for: K4, Numbers and Operations, whole numbers up to the millions
# ('Numerical Misconception', 'Is 5,000 greater or less than 500,000?', '<5,000 is less than 500,000 because 5 is less than 500,000.>')
# ✅ Dataset generation complete. Saved at: /content/gdrive/My Drive/student_fine_tuned_results.csv
